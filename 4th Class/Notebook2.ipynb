# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.sample(1)

# %%
data = data.drop(columns=['Suppressed', 'Series_title_5'])

# %%
data.sample(1)

# %%
data.STATUS.value_counts()

# %%
data['STATUS'] = data['STATUS'].map({'R': 10, 'C': 100})

# it changes the values based on the map I provide.

# %%
data.STATUS.value_counts()

# %%
data.sample(1)

# %%
partial_c_data = data[data['STATUS'] == 'C']

# dividing into a subgroup based on a filter I choose.

# %%
cond = data['STATUS'] == 'C'

data.loc[cond, 'STATUS'] = 100

# 1. a specific subgroup of the data
# 2. the column I want to change ( it can be any column)

# %%
data.STATUS.value_counts()

# %%
data.Magnitude.value_counts()

# %%
#anonymous function

data['Magnitude'] = data['Magnitude'].apply(lambda y: y**2)

# no more lambda function here.

# %%
data['Series_title_2'] = data['Series_title_2'].apply(lambda x: x.upper())

# %%
data.sample(1)

# %%
data.Magnitude.value_counts()

# %%
data[data.Series_title_1.str.contains('income')].shape
# Series_title_1 contains the word 'income' or not.

# %%
data.sample(1)

# %%
partial_columns = data[['Period', 'STATUS', 'Magnitude']] # column filtering/selection

# %%
partial_columns.shape

# %%
partial_columns.sample(1)

# %%
partial_c_data.shape

# %%
partial_another = data[data.Series_title_3=='Current']

# %%
partial_another.shape

# %%
# partial_another
# partial_c_data 

df = pd.concat([partial_c_data, partial_another])

# %%
df.shape

# %%
data.drop_duplicates(subset=['unique_key_column'])
