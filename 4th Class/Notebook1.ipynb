# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
type(data)

# %%
data.head() # first 5 rows

# %%
data.tail() # last 5 rows

# %%
data.sample(5) # random 5 rows

# %%
data.shape # (rows, columns)

# %%
columns = data.columns

# %%
columns[0]

# %%
data.isna().sum() # number of missing values in each column

# %%
data.dtypes # data types of each column

# %%
# data = data.fillna('*')

# data = data.dropna()

# %%
data.head()

# %%
data = data.drop(columns=['Series_title_5', 'Suppressed'])

# %%
data.head()

# %%
data.isna().sum()

# %%
data[data.UNITS == 'Dollars'] # filter rows

# %%
data.Series_title_1.value_counts()

# %%
unique_values = data.Series_reference.unique()

# %%
data.Series_reference.nunique()

# %%
data['new_column'] = data.UNITS + ' ' + data.Series_title_1

# %%
def unit_change(x):
    if x == 'Dollars':
        return '$'
    else:
        return x
    
data['NEW_UNITS'] = data.UNITS.apply(unit_change)

# %%
data.head()
